# %% [markdown]
# # pandas 실습 - 데이터 특성을 알아보자

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. pandas와 numpy 라이브러리를 Import 합니다.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
import pandas as pd

pd.read_csv(url, delimiter='\t').to_csv('chipotle.tsv', sep="\t", index=False)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. 데이터 셋을 불러옵니다.

# %%
chipo = pd.read_csv("chipotle.tsv", sep = '\t')
chipo["item_price2"] = chipo['item_price'].apply(lambda x : float(x[1:]) )
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 3. head 함수를 통해 처음 10개 행을 살펴봅시다.

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price  item_price2
# 0                                                NaN     $2.39          2.39
# 1                                       [Clementine]     $3.39          3.39
# ...

# %%
import numpy as np

mean_and_round = lambda x: round(np.mean(x), 2)

grouped_df = chipo.groupby('item_name').agg({
    "quantity": [ sum, max ],
    'item_price2': [ ('M&R', mean_and_round), ('sum', sum) ],
}).sort_values(('quantity', 'sum'), ascending=False)


grouped_df
# Out:
#                                       quantity     item_price2
#                                            sum max         M&R      sum
# item_name
# Chicken Bowl                               761   3       10.11  7342.73
# Chicken Burrito                            591   4       10.08  5575.82
# Chips and Guacamole                        506   4        4.60  2201.04
# Steak Burrito                              386   3       10.47  3851.43
# Canned Soft Drink                          351   4        1.46   438.75
# Chips                                      230   3        2.34   494.34
# Steak Bowl                                 221   3       10.71  2260.19
# Bottled Water                              211  10        1.87   302.56
# Chips and Fresh Tomato Salsa               130  15        3.29   361.36
# Canned Soda                                126   4        1.32   137.34
# Chicken Salad Bowl                         123   2       11.17  1228.75
# ...

# %%
# Out:
#                                       quantity     item_price2           \
#                                            sum max        mean      sum
# item_name
# Chicken Bowl                               761   3   10.113953  7342.73
# Chicken Burrito                            591   4   10.082857  5575.82
# Steak Burrito                              386   3   10.465842  3851.43
# Steak Bowl                                 221   3   10.711801  2260.19
# Chips and Guacamole                        506   4    4.595073  2201.04
# Chicken Salad Bowl                         123   2   11.170455  1228.75
# Chicken Soft Tacos                         120   2    9.635565  1108.09
# Veggie Burrito                              97   3    9.839684   934.77
# Barbacoa Burrito                            91   1    9.832418   894.75
# Veggie Bowl                                 87   2   10.211647   867.99
# Carnitas Bowl                               71   3   10.833971   736.71
# ...

# %%
pivot_df = chipo.pivot_table(index="order_id", values="quantity", columns="item_name", aggfunc="sum").fillna(0)
pivot_df.to_csv("result.csv",encoding="cp949")

# %%
chipo["item_price2"].sum()
# Out:
# 34500.16

# %%
adf = adf.sort_values("quantity", ascending=False)
adf["profit"] = adf.apply(lambda x: x["quantity"] * x["item_price_2"], axis=1)

# %%
adf.sort_values("profit", ascending=False)
# Out:
#                      quantity  item_price_2       profit
# item_name
# Chicken Bowl              761     10.113953  7696.718361
# Chicken Burrito           591     10.082857  5958.968571
# Steak Burrito             386     10.465842  4039.815163
# Steak Bowl                221     10.711801  2367.308009
# Chips and Guacamole       506      4.595073  2325.106973

# %% [markdown]
# # 500개 미만 판매량을 가진 메뉴 중에서 총 매출이 2000$ 이상인 행만 추려봅시다.

# %%
adf[ (adf["quantity"] < 500) & (adf["profit"] >= 2000)]
# Out:
#                quantity  item_price_2       profit
# item_name
# Steak Burrito       386     10.465842  4039.815163
# Steak Bowl          221     10.711801  2367.308009

# %% [markdown]
# #  또는 수량이 50 이하인 행

# %%
adf[ ((adf["quantity"] < 500) & (adf["profit"] >= 2000)) | (adf["quantity"] < 50) ]
# Out:
#                                        quantity  item_price_2       profit
# item_name
# Steak Burrito                               386     10.465842  4039.815163
# Steak Bowl                                  221     10.711801  2367.308009
# Chips and Tomatillo Green Chili Salsa        45      3.087209   138.924419
# Carnitas Soft Tacos                          40      9.398500   375.940000
# Steak Crispy Tacos                           36     10.209714   367.549714
# Chips and Tomatillo-Green Chili Salsa        33      2.544194    83.958387
# Steak Salad Bowl                             31     11.847931   367.285862
# Nantucket Nectar                             29      3.641111   105.592222
# Chips and Tomatillo-Red Chili Salsa          25      2.987500    74.687500
# Barbacoa Soft Tacos                          25     10.018400   250.460000
# Chips and Roasted Chili Corn Salsa           23      3.084091    70.934091
# ...

# %%
chipo["item_name"].sort_values().unique()
# Out:
# array(['6 Pack Soft Drink', 'Barbacoa Bowl', 'Barbacoa Burrito',
#        'Barbacoa Crispy Tacos', 'Barbacoa Salad Bowl',
#        'Barbacoa Soft Tacos', 'Bottled Water', 'Bowl', 'Burrito',
#        'Canned Soda', 'Canned Soft Drink', 'Carnitas Bowl',
#        'Carnitas Burrito', 'Carnitas Crispy Tacos', 'Carnitas Salad',
#        'Carnitas Salad Bowl', 'Carnitas Soft Tacos', 'Chicken Bowl',
#        'Chicken Burrito', 'Chicken Crispy Tacos', 'Chicken Salad',
#        'Chicken Salad Bowl', 'Chicken Soft Tacos', 'Chips',
#        'Chips and Fresh Tomato Salsa', 'Chips and Guacamole',
#        'Chips and Mild Fresh Tomato Salsa',
#        'Chips and Roasted Chili Corn Salsa',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Tomatillo Green Chili Salsa',
#        'Chips and Tomatillo Red Chili Salsa',
#        'Chips and Tomatillo-Green Chili Salsa',
#        'Chips and Tomatillo-Red Chili Salsa', 'Crispy Tacos', 'Izze',
# ...

# %% [markdown]
# # chicken이라는 단어가 들어간 메뉴의 가지수는 얼마나 될까?

# %%
chipo[ chipo["item_name"].str.contains("(?i)chicken") ]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4619      1834         1    Chicken Salad Bowl
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# ...

# %%
chipo[ chipo["item_name"].str.contains("(?i)chicken") ]

# %% [markdown]
# # Cicken와 Salad가 모두 들어간 메뉴의 가지수는 얼마나 될까?

# %%
filtered = chipo[ (chipo["item_name"].str.contains("(?i)chicken")) & (chipo["item_name"].str.contains("(?i)salad")) ]
filtered["item_name"].unique()
# Out:
# array(['Chicken Salad Bowl', 'Chicken Salad'], dtype=object)

# %%
ddf = chipo[ chipo["item_name"].str.contains("Chicken") | chipo["item_name"].str.contains("Salsa") ]
ddf["item_name"].unique().shape[0]
# Out:
# 14

# %% [markdown]
# # 아래와 같이 각 주문에 대한 주문자 이름의 DF가 있을때, 주문데이터와 left 조인 해봅시다.

# %%
orderer_name = [
    [1, "louis"],
    [2, "nancy"],
    [3, "bob"],
    [5500, "alice"]
]

columns = [ "order_id", "orderer_name"]

name_df = pd.DataFrame(orderer_name, columns=columns)
name_df = name_df.set_index("order_id")
name_df
# Out:
#          orderer_name
# order_id
# 1               louis
# 2               nancy
# 3                 bob
# 5500            alice

# %%
pd.merge(name_df,chipo, how="inner", left_index=True, right_on="order_id").head(10)
# Out:
#   orderer_name  order_id  quantity                              item_name  \
# 0        louis         1         1           Chips and Fresh Tomato Salsa
# 1        louis         1         1                                   Izze
# 2        louis         1         1                       Nantucket Nectar
# 3        louis         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        nancy         2         2                           Chicken Bowl
# 5          bob         3         1                           Chicken Bowl
# 6          bob         3         1                          Side of Chips
#
#                                   choice_description item_price  item_price2
# 0                                                NaN     $2.39          2.39
# 1                                       [Clementine]     $3.39          3.39
# 2                                            [Apple]     $3.39          3.39
# ...

# %%
# Out:
#    order_id orderer_name  quantity                              item_name  \
# 0         1        louis         1           Chips and Fresh Tomato Salsa
# 1         1        louis         1                                   Izze
# 2         1        louis         1                       Nantucket Nectar
# 3         1        louis         1  Chips and Tomatillo-Green Chili Salsa
# 4         2        nancy         2                           Chicken Bowl
# 5         3          bob         1                           Chicken Bowl
# 6         3          bob         1                          Side of Chips
#
#                                   choice_description item_price
# 0                                               정보없음     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                               정보없음     $2.39
# ...

# %%
chipo["item_price_2"] = chipo["item_price"].apply(lambda x: float(x[1:]) )
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price  item_price_2
# 0                                                NaN     $2.39           2.39
# 1                                       [Clementine]     $3.39           3.39
# ...

# %%
adf = chipo.groupby(by="item_name").agg({
    "quantity":"sum",
    "item_price_2": "mean"
})
adf = adf.sort_values('quantity',ascending=False)
adf
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 adf = chipo.groupby(by="item_name").agg({
#       2     "quantity":"sum",
#       3     "item_price_2": "mean"
#       4 })
#       5 adf = adf.sort_values('quantity',ascending=False)
#       6 adf
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\generic.py:869, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     866 func = maybe_mangle_lambdas(func)
#     868 op = GroupByApply(self, func, args, kwargs)
# --> 869 result = op.agg()
#     870 if not is_dict_like(func) and result is not None:
#     871     return result
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:168, in Apply.agg(self)
#     165     return self.apply_str()
#     167 if is_dict_like(arg):
# ...

# %%
adf = chipo.groupby(by="item_name").sum().drop("order_id",axis=1)
adf.sort_values("quantity", ascending=False)
# Out:
#                                        quantity  item_price_2
# item_name
# Chicken Bowl                                761       7342.73
# Chicken Burrito                             591       5575.82
# Chips and Guacamole                         506       2201.04
# Steak Burrito                               386       3851.43
# Canned Soft Drink                           351        438.75
# Chips                                       230        494.34
# Steak Bowl                                  221       2260.19
# Bottled Water                               211        302.56
# Chips and Fresh Tomato Salsa                130        361.36
# Canned Soda                                 126        137.34
# Chicken Salad Bowl                          123       1228.75
# Chicken Soft Tacos                          120       1108.09
# Side of Chips                               110        185.90
# Veggie Burrito                               97        934.77
# ...

# %% [markdown]
# # choice_description 컬럼의 결측값을 채워봅시다
# ---

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. 데이터셋의 크기를 살펴봅시다.

# %%
# Solution 1

chipo.shape
# Out:
# (4622, 6)

# %%
chipo.index.size # index의 size로 살펴보는 방법
# Out:
# 4622

# %%
chipo.info() # info 함수를 이용하는 방법
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %% [markdown]
# ### Step 5. 데이터의 컬럼은 몇개인지 살펴봅시다.

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# ### Step 6. 컬럼명들을 살펴봅시다.

# %%
chipo.columns
# Out:
# Index([u'order_id', u'quantity', u'item_name', u'choice_description',
#        u'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 7. 데이터 셋은 어떻게 인덱싱 되어 있을까요?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# 0부터 4622의 연속된 정수(순번)로 인덱싱 되어 있습니다.

# %% [markdown]
# ### Step 8. 가장 인기 많은 메뉴는 무엇일까요?

# %%
c = chipo.groupby('item_name')
c = c.sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# ### Step 9. 가장 많이 선택된 사이드 메뉴(choice_description)는 무엇일까요?

# %%
c = chipo.groupby('choice_description').sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Diet Coke 159
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# ### Step 10. 총 주문 수를 구해봅시다.

# %%
total_items_orders = chipo.quantity.sum()
total_items_orders
# Out:
# 4972

# %% [markdown]
# ### Step 11. 정수값의 price 컬럼을 float으로 바꾸어 봅시다.

# %% [markdown]
# #### Step 11.a. Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Step 11.b. 람다를 활용해 문자열을 float으로 바꾸어 봅시다.

# %%
dollarizer = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(dollarizer)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %% [markdown]
# #### Step 11.c. 바뀐 컬럼의 타입을 확인해 보기.

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 12. 총 수입 금액을 구해봅시다.

# %%
revenue = (chipo['quantity']* chipo['item_price']).sum()

print('Revenue was: $' + str(np.round(revenue,2)))
# Out:
# Revenue was: $39237.02

# %% [markdown]
# ### Step 13. 각 주문의 평균 금액을 구해 봅시다.

# %%
# Solution 1

chipo['revenue'] = chipo['quantity'] * chipo['item_price']
order_grouped = chipo.groupby(by=['order_id']).sum()
order_grouped.mean()['revenue']
# Out:
# 21.39423118865867

# %%
# Solution 2

chipo.groupby(by=['order_id']).sum().mean()['revenue']
# Out:
# 21.39423118865867

# %% [markdown]
# ### Step 14. 메뉴의 가지수를 구해봅시다.

# %%
chipo.item_name.value_counts().count()
# Out:
# 50
