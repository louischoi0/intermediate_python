# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}

data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['A', 'B', 'C']
values = [1, 10, 100]

plt.bar(names, values)

plt.suptitle('Categorical Plotting: Bar')
plt.show()

# %%
names = ['A', 'B', 'C']
values = [1, 10, 100]

plt.scatter(names, values)

plt.suptitle('Categorical Plotting: Dot')
plt.show()

# %%
names = ['A', 'B', 'C']
values = [1, 10, 100]

plt.plot(names, values)

plt.suptitle('Categorical Plotting: Line')
plt.show()

# %%
names = ['A', 'B', 'C']
values = [1, 10, 100]

plt.figure(figsize=(12, 4))

plt.subplot(131)
plt.bar(names, values)

plt.subplot(132)
plt.scatter(names, values)

plt.subplot(133)
plt.plot(names, values,'g-')

plt.suptitle('Categorical Plotting')
plt.show()

# %%
x = np.linspace(0, 2, 100)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend();  # Add a legend.

# %%
import numpy as np

x = np.linspace(0, 2, 100)  # Sample data.
fig, ax = plt.subplots(figsize=(8, 4.2), layout='constrained')

ax.plot(x, x, 'g-', label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**2, 'b+', label='cubic')  # ... and some more.
ax.plot(x, x**3, 'rx', label='cubic')  # ... and some more.

ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.legend();  # Add a legend.

# %%
ax.plot(x, x, label='linear')  # Plot some data on the axes.
plt.show()

# %%
df = pd.read_csv("expenses.csv", index_col=0)
df
# Out:
#            Date    Dep  Amount
# 0    2022-07-01     HR    9000
# 1    2022-07-01     HR    5000
# 2    2022-07-01     HR    5000
# 3    2022-07-01     HR    9000
# 4    2022-07-01     HR   30000
# ..          ...    ...     ...
# 220  2022-07-29    R&D   35000
# 221  2022-07-29    R&D   12000
# 222  2022-07-29    R&D   26000
# 223  2022-07-29  SALES   19000
# 224  2022-07-29  SALES   37000
#
# [225 rows x 3 columns]

# %%
df["Amount2"] = df["Amount"].apply(lambda x: "{:,}".format(x))
df
# Out:
#            Date    Dep  Amount Amount2
# 0    2022-07-01     HR    5000   5,000
# 1    2022-07-01     HR   50000  50,000
# 2    2022-07-01  SALES   26000  26,000
# 3    2022-07-02     HR   35000  35,000
# 4    2022-07-02     HR   33000  33,000
# ..          ...    ...     ...     ...
# 231  2022-07-29     HR    5000   5,000
# 232  2022-07-29  SALES   31000  31,000
# 233  2022-07-29  SALES   15000  15,000
# 234  2022-07-29  SALES   48000  48,000
# 235  2022-07-29  SALES   50000  50,000
#
# [236 rows x 4 columns]

# %%
sdf = df.groupby("Dep").sum()

names = sdf.index
values = sdf["Amount"]

plt.figure(figsize=(12, 4))
plt.bar(names, values)
# Out:
# <BarContainer object of 3 artists>

# %%
sdf = df.groupby("Date").sum()

plt.bar(range(0, sdf.index.size), sdf["Amount"].values)
# Out:
# <BarContainer object of 29 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

# 그림 사이즈, 바 굵기 조정
fig, ax = plt.subplots(figsize=(12,6))
bar_width = 0.25

# 연도가 4개이므로 0, 1, 2, 3 위치를 기준으로 삼음
index = np.arange(4)
year = np.array([2022, 2023,2024,2025])

dep_index = sdf.index

# 각 연도별로 3개 샵의 bar를 순서대로 나타내는 과정, 각 그래프는 0.25의 간격을 두고 그려짐
b1 = plt.bar(dep_index, sdf["Amount"], bar_width, color='red')
#b2 = plt.bar(year + bar_width, [5,6,7,8], bar_width, color='blue')
#b3 = plt.bar(year + (2*bar_width), [9,10,11,12], bar_width, color='green')

# x축 위치를 정 가운데로 조정하고 x축의 텍스트를 year 정보와 매칭
plt.xticks(dep_index)

# x축, y축 이름 및 범례 설정
plt.xlabel('Department', size = 13)
plt.ylabel('Expense', size = 13)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sdf = df.groupby('Dep').sum()

# %%
sdf["Amount"]
# Out:
# Dep
# HR       2294000
# R&D      1779000
# SALES    1739000
# Name: Amount, dtype: int64

# %%
df = pd.read_csv('profits.csv', index_col=0)
df
# Out:
#                  BTC       ETH       XRP      DOGE
# 2022-07-01 -0.006358 -0.018568  0.014529  0.015404
# 2022-07-02  0.012663  0.009275  0.011195 -0.011618
# 2022-07-03  0.027109  0.000453  0.015653 -0.011856
# 2022-07-04  0.009966 -0.007314 -0.015878 -0.012945
# 2022-07-05  0.003667 -0.002012 -0.006906  0.006794
# 2022-07-06 -0.005513  0.005931 -0.015723  0.027456
# 2022-07-07 -0.009449  0.002073  0.007085 -0.012592
# 2022-07-08 -0.010249 -0.005849  0.017557  0.011672
# 2022-07-09 -0.003803  0.028315 -0.013292 -0.017448
# 2022-07-10  0.002033  0.018347  0.000411 -0.000905
# 2022-07-11  0.005215  0.016734 -0.004523 -0.010910
# 2022-07-12 -0.015281 -0.012611  0.009201  0.009516
# 2022-07-13 -0.003905 -0.009627 -0.002744  0.004159
# 2022-07-14  0.000974  0.025979  0.003137 -0.012905
# 2022-07-15 -0.018056  0.027821 -0.014814 -0.014155
# 2022-07-16 -0.015141 -0.000972 -0.004849  0.009663
# 2022-07-17  0.017262  0.002001  0.018937 -0.000834
# ...

# %%
(df["BTC"] + 1).values.cumprod() * 1000
# Out:
# array([ 993.64221833, 1006.22506355, 1033.50232386, 1043.8018498 ,
#        1047.62965645, 1041.85452546, 1032.01013112, 1021.43332757,
#        1017.54842181, 1019.61734046, 1024.93477269, 1009.2731646 ,
#        1005.33197099, 1006.31099133,  988.14054043,  973.17902148,
#         989.97804257, 1009.67898949, 1038.44350865, 1018.14482717,
#        1000.78730032, 1016.17570855, 1039.66774963, 1063.72255581,
#        1052.36577805, 1078.8370056 , 1074.56258501, 1097.59207721,
#        1119.92240266, 1128.90152196, 1151.21203646])

# %%
plt.figure()


plt.plot((df["BTC"] + 1).values.cumprod() * 1000, label="BTC")
plt.plot((df["ETH"] + 1).values.cumprod() * 1000, label="ETH")
plt.plot((df["XRP"] + 1).values.cumprod() * 1000, label="XRP")
plt.plot((df["DOGE"] + 1).values.cumprod() * 1000, label="DOGE")

plt.legend()

# %%
weight = np.array([0.3,0.4,0.2,0.1])

w = (df.values + 1) @ weight

plt.figure()

plt.plot((df["BTC"] + 1).values.cumprod() * 1000, label="BTC")
plt.plot((df["ETH"] + 1).values.cumprod() * 1000, label="ETH")
plt.plot((df["XRP"] + 1).values.cumprod() * 1000, label="XRP")
plt.plot((df["DOGE"] + 1).values.cumprod() * 1000, label="DOGE")
plt.plot(w * 1000, label="Portfolio")

plt.legend()
