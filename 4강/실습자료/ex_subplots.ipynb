# %%
import pandas as pd

df = pd.read_csv("chipolet.tsv", delimiter="\t")
df["item_price_2"] = df["item_price"].apply(lambda x: float(x[1:]))
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                   NaN     $2.39
# ...

# %%
import matplotlib.pyplot as plt

revenue = df.groupby(by="item_name").sum()["item_price_2"].sort_values(ascending=False).iloc[:4]
quantity = df.groupby(by="item_name").sum()["quantity"].sort_values(ascending=False).iloc[:4]


plt.figure(figsize=(16, 4))

plt.subplot(131)
plt.xlabel("menu")
plt.ylabel("revenue")
plt.bar(revenue.index, revenue.values)

plt.subplot(132)
plt.bar(quantity.index, quantity.values)
# Out:
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as plt

revenue = df.groupby(by="item_name").sum()["item_price_2"].sort_values(ascending=False).iloc[:4]
quantity = df.groupby(by="item_name").sum()["quantity"].sort_values(ascending=False).iloc[:4]


plt.figure(figsize=(16, 4))

plt.subplot(131)
plt.bar(revenue.index, revenue.values)

plt.subplot(132)
plt.bar(quantity.index, quantity.values)

grouped = df.groupby(by="item_name").sum()
grouped = grouped[ grouped["item_price"] <= 2000 ]

plt.subplot(133)
plt.scatter(grouped["quantity"], grouped["item_price_2"])
# Out:
#                                        order_id  quantity  item_price_2
# item_name
# 6 Pack Soft Drink                         52322        55        356.95
# Barbacoa Bowl                             53972        66        672.36
# Barbacoa Burrito                          74718        91        894.75
# Barbacoa Crispy Tacos                      5613        12        120.21
# Barbacoa Salad Bowl                        9708        10        106.40
# Barbacoa Soft Tacos                       18725        25        250.46
# Bottled Water                            175944       211        302.56
# Bowl                                        472         4         29.60
# Burrito                                    1550         6         44.40
# Canned Soda                               76396       126        137.34
# Canned Soft Drink                        304753       351        438.75
# Carnitas Bowl                             62742        71        736.71
# ...

# %%
import matplotlib.pyplot as plt

revenue = df.groupby(by="item_name").sum()["item_price_2"].sort_values(ascending=False).iloc[:4]
quantity = df.groupby(by="item_name").sum()["quantity"].sort_values(ascending=False).iloc[:4]

plt.figure(figsize=(12, 6))

plt.subplot(2,3,1)
plt.bar(revenue.index, revenue.values,label="revenue per menu")
plt.legend()

plt.subplot(232)
plt.bar(quantity.index, quantity.values)

grouped = df.groupby(by="item_name").sum()
grouped = grouped[ grouped["item_price_2"] < 2000 ]

plt.subplot(233)
plt.scatter(grouped["quantity"], grouped["item_price_2"])

plt.subplot(235)
plt.bar(["Chicken", "Salsa"], [1700, 453])

ddf = df.groupby(by="order_id").sum()["quantity"]
d = ddf.sort_values(ascending=False)
p = df.groupby(by="order_id").sum()["item_price_2"].sort_values(ascending=False) / 10
plt.subplot(234)
plt.plot(range(0,d.index.size), d, label="quantity per order")
plt.plot(range(0,p.index.size), p, label="profit per order")
plt.legend(loc="upper left")

plt.subplot(236)
plt.bar(order_df.index, order_df.values)
# Out:
# <BarContainer object of 5 artists>

# %%
users = [ "louis", "nancy", "bob", "alice", "paul" ]
import numpy as np
index = df["order_id"].unique()
values = list(  users[np.random.randint(0, len(users))] for _ in index)

user_df = pd.DataFrame(data=zip(index, values),columns=["order_id", "orderer_name"])
order_df = pd.merge(df, user_df, left_on="order_id", right_on="order_id", how="left")
order_df = order_df.groupby(by="orderer_name").sum()["item_price_2"]

# %%
salsa_sales = df[ df["item_name"].str.contains("Salsa")]["quantity"].sum()
salsa_sales
# Out:
# 325
