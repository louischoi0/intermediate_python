# %% [markdown]
# # 넘파이 배열 다루기 실습
# ---

# %%
import numpy as np

# 조건에 일치하는 원소들만 가져오기.

revenue  = np.array([
    300000, 340000, 320000, 360000, 
    440000, 140000, 180000, 340000, 
    330000, 290000, 280000, 380000, 
    170000, 140000, 230000, 390000, 
    400000, 350000, 380000, 150000, 
    110000, 240000, 380000, 380000, 
    340000, 420000, 150000, 130000, 
    360000, 320000, 250000
])

# %%
# 200000 이하인 원소들만 슬라이싱 하기
indices = np.where( revenue < 200000 )
revenue[indices]
# Out:
# array([140000, 180000, 170000, 140000, 150000, 110000, 150000, 130000])

# %% [markdown]
# # 1차원 벡터와 스칼라 브로드 캐스팅 연산
# ---
# ![image.png](attachment:image.png)

# %%
import numpy as np

a = np.array([0,1,2])
a + 5
# Out:
# array([5, 6, 7])

# %% [markdown]
# # 2차원 행렬과 벡터간 브로드 캐스팅 연산
# ---
#
# ![image.png](attachment:image.png)

# %%
a = np.ones((3,3))
b = np.arange(3)

a + b
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.],
#        [1., 2., 3.]])

# %% [markdown]
# # 3 * 1 행렬과 3 벡터의 브로드 캐스팅 연산
#
# ![image.png](attachment:image.png)

# %%
a = np.arange(3).reshape((3,1))
b = np.arange(3)

a + b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])
